# %% [markdown]
# <a href="https://colab.research.google.com/github/nefetorve/Advent-of-Code/blob/main/2021/day_6/day6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = ["3,4,3,1,2"]
with open('input.txt') as f:
    data = f.read().splitlines()
new_data =[]
for element in data:
  new_data.append(element.split(","))

# %%
data = []
for list in new_data:
  for element in list:
    element = int(element)
    data.append(element)

# %%
data
# Out:
# [1,
#  2,
#  1,
#  3,
#  2,
#  1,
#  1,
#  5,
#  1,
#  4,
#  1,
#  2,
#  1,
#  4,
#  3,
#  3,
#  5,
#  1,
#  1,
#  3,
#  5,
#  3,
#  4,
#  5,
#  5,
#  4,
#  3,
#  1,
#  1,
#  4,
#  3,
#  1,
#  5,
#  2,
#  5,
#  2,
#  4,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  4,
#  1,
#  4,
#  4,
#  4,
#  1,
#  4,
#  4,
#  1,
#  4,
#  2,
#  1,
#  1,
#  1,
#  1,
#  3,
#  5,
#  4,
#  3,
#  3,
#  5,
#  4,
#  1,
#  3,
#  1,
#  1,
#  2,
#  1,
#  1,
#  1,
#  4,
#  1,
#  2,
#  5,
#  2,
#  3,
#  1,
#  1,
#  1,
#  2,
#  1,
#  5,
#  1,
#  1,
#  1,
#  4,
#  4,
#  4,
#  1,
#  5,
#  1,
#  2,
#  3,
#  2,
#  2,
#  2,
#  1,
#  1,
#  4,
#  3,
#  1,
#  4,
#  4,
#  2,
#  1,
#  1,
#  5,
#  1,
#  1,
#  1,
#  3,
#  1,
#  2,
#  1,
#  1,
#  1,
#  1,
#  4,
#  5,
#  5,
#  2,
#  3,
#  4,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  1,
#  5,
#  5,
#  3,
#  5,
#  4,
#  3,
#  1,
#  3,
#  1,
#  1,
#  5,
#  1,
#  1,
#  4,
#  2,
#  1,
#  3,
#  1,
#  1,
#  4,
#  3,
#  1,
#  5,
#  1,
#  1,
#  3,
#  4,
#  2,
#  2,
#  1,
#  1,
#  2,
# ...

# %%
reset_lanternfish = 6
new_lanternfish = 8 
day_for_fish = 256

# %%
data_dict = {i:0 for i in range(9)}
for i in set(data):
  data_dict[i] = data.count(i) 
data_dict
# Out:
# {0: 0, 1: 129, 2: 42, 3: 44, 4: 45, 5: 40, 6: 0, 7: 0, 8: 0}

# %%
for day in range(day_for_fish):
  value_0 = data_dict[0]
  for i in range(0,8):
    data_dict[i] = data_dict[i+1]
  data_dict[8] = value_0
  data_dict[6] += value_0

# %%
sum(data_dict.values())
# Out:
# 1653559299811
