# %% [markdown]
# <a href="https://colab.research.google.com/github/nefetorve/Advent-of-Code/blob/main/2021/day_5/day5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
values = ["0,9 -> 5,9",
"8,0 -> 0,8",
"9,4 -> 3,4",
"2,2 -> 2,1",
"7,0 -> 7,4",
"6,4 -> 2,0",
"0,9 -> 2,9",
"3,4 -> 1,4",
"0,0 -> 8,8",
"5,5 -> 8,2"]

with open('input.txt') as f:
    values = f.read().splitlines()
new_values = []
for value in values:
  value = value.split("->")
  for _,v in enumerate(value):
    v = v.split(",")
    new_values.append(v)

# %%
pair = []
values = []
for value in new_values:
  for _,i in enumerate(value):
    pair.append(int(i))
    if _ >= 1:
      values.append(pair)
      pair = []

# %%
def every_first_element(values):
    second_values = []

    for index in range(0, len(values), 2):
        second_values.append(values[index])

    return second_values 
def every_second_element(values):
    second_values = []

    for index in range(1, len(values), 2):
        second_values.append(values[index])

    return second_values

# %%
element_1 = every_first_element(values)
element_2 =  every_second_element(values)

# %%
import numpy as np
element_1 = np.array(element_1)
element_2 = np.array(element_2)

# %%
mask = (element_1 == element_2)

# %%
mask_element = mask*element_1

# %%
mask_element
# Out:
# array([[580,   0],
#        [  0,   0],
#        [300,   0],
#        [ 27,   0],
#        [  0, 430],
#        [488,   0],
#        [824,   0],
#        [  0,   0],
#        [967,   0],
#        [  0, 139],
#        [671,   0],
#        [270,   0],
#        [682,   0],
#        [  0,   0],
#        [  0, 635],
#        [228,   0],
#        [  0,   0],
#        [180,   0],
#        [  0,   0],
#        [  0,  11],
#        [  0,   0],
#        [  0,   0],
#        [  0,   0],
#        [  0,   0],
#        [940,   0],
#        [  0, 490],
#        [  0,   0],
#        [327,   0],
#        [  0,   0],
#        [  0,   0],
#        [  0,   0],
#        [  0, 475],
#        [  0,   0],
#        [  0,   0],
#        [  0, 101],
#        [  0, 321],
#        [  0, 586],
#        [  0,   0],
#        [  0,   0],
#        [  0, 798],
#        [  0, 711],
#        [601,   0],
#        [ 32,   0],
#        [  0, 309],
#        [ 92,   0],
#        [  0,   0],
#        [  0, 630],
# ...

# %%
points = []
values_points_x_or_y = []
for _,mask in enumerate(mask_element):
    value = None
    if mask[0] !=0:
      idx_value = 0 
      value = mask[idx_value]
      idx = 1
    if mask[1] !=0:
      idx_value = 1
      value = mask[idx_value]
      idx = 0
    if value!=None:
      if element_1[_][idx]-element_2[_][idx] >= 0: 
        i = -1
        values = np.arange(element_1[_][idx],element_2[_][idx]+i,i)
      else: 
        i = 1
        values = np.arange(element_1[_][idx],element_2[_][idx]+i,i)
      points_per_position = (value,idx_value)
      points.append(points_per_position)
      values_points_x_or_y.append(values)


      print(value,values,idx_value)
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
#  373 374 375 376 377 378 379] 1
# 489 [196 197 198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213
#  214 215 216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231
#  232 233 234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249
#  250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267
#  268 269 270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285
#  286 287 288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303
#  304 305 306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321
#  322 323 324 325 326 327 328 329 330 331 332 333 334 335 336 337 338 339
#  340 341 342 343 344 345 346 347 348 349 350 351 352 353 354 355 356 357
#  358 359 360 361 362 363 364 365 366 367 368 369 370 371 372 373 374 375
#  376 377 378 379 380 381 382 383 384 385 386 387 388 389 390 391 392 393
# ...

# %%
points
# Out:
# [(580, 0),
#  (300, 0),
#  (27, 0),
#  (430, 1),
#  (488, 0),
#  (824, 0),
#  (967, 0),
#  (139, 1),
#  (671, 0),
#  (270, 0),
#  (682, 0),
#  (635, 1),
#  (228, 0),
#  (180, 0),
#  (11, 1),
#  (940, 0),
#  (490, 1),
#  (327, 0),
#  (475, 1),
#  (101, 1),
#  (321, 1),
#  (586, 1),
#  (798, 1),
#  (711, 1),
#  (601, 0),
#  (32, 0),
#  (309, 1),
#  (92, 0),
#  (630, 1),
#  (300, 1),
#  (348, 1),
#  (489, 1),
#  (238, 1),
#  (28, 1),
#  (365, 0),
#  (925, 0),
#  (488, 0),
#  (515, 0),
#  (630, 1),
#  (315, 0),
#  (351, 0),
#  (663, 1),
#  (644, 0),
#  (192, 1),
#  (440, 0),
#  (971, 1),
#  (228, 1),
#  (760, 1),
#  (767, 1),
#  (626, 1),
#  (751, 0),
#  (533, 1),
#  (567, 0),
#  (47, 1),
#  (823, 0),
#  (378, 0),
#  (317, 0),
#  (954, 1),
#  (392, 1),
#  (351, 1),
#  (417, 0),
#  (151, 0),
#  (366, 1),
#  (644, 1),
#  (861, 0),
#  (759, 1),
#  (129, 0),
#  (696, 1),
#  (901, 0),
#  (785, 0),
#  (553, 0),
#  (957, 1),
#  (241, 0),
#  (363, 1),
#  (591, 0),
#  (485, 1),
#  (204, 0),
# ...

# %%
new_array = []
for _,point in enumerate(values_points_x_or_y):
  for __,z in enumerate(point):
    new_value = points[_][0]
    if points[_][1] == 0:
      elements = [new_value,z]
    if points[_][1] == 1:
      elements = [z,new_value]
    new_array.append(elements)

# %%
# unique = []
# for x in new_array:
#   if x not in unique:
#     unique.append(x)

# %%
import pandas as pd
df = pd.DataFrame(new_array)
df = df.rename(columns={0: 'x',1:"y"})

# %%
df_duplicate = df[df.duplicated(['x',"y"])]

# %%
df_duplicate = df_duplicate.values.tolist()
df =  df.values.tolist()
df_duplicate
# Out:
# [[682, 635],
#  [580, 635],
#  [488, 635],
#  [488, 490],
#  [580, 490],
#  [682, 490],
#  [327, 475],
#  [488, 475],
#  [580, 475],
#  [682, 475],
#  [327, 321],
#  [488, 321],
#  [671, 321],
#  [682, 321],
#  [228, 586],
#  [180, 586],
#  [580, 798],
#  [488, 798],
#  [327, 798],
#  [228, 798],
#  [180, 798],
#  [27, 711],
#  [601, 139],
#  [601, 321],
#  [601, 475],
#  [601, 490],
#  [601, 635],
#  [327, 309],
#  [92, 101],
#  [327, 300],
#  [488, 300],
#  [601, 300],
#  [327, 348],
#  [228, 489],
#  [327, 489],
#  [488, 489],
#  [580, 489],
#  [601, 489],
#  [682, 489],
#  [682, 238],
#  [671, 238],
#  [601, 238],
#  [488, 238],
#  [327, 238],
#  [365, 489],
#  [365, 475],
#  [488, 799],
#  [488, 798],
#  [488, 797],
#  [488, 796],
#  [488, 795],
#  [488, 794],
#  [488, 793],
#  [488, 792],
#  [488, 791],
#  [488, 790],
#  [488, 789],
#  [488, 788],
#  [488, 787],
#  [488, 786],
#  [488, 785],
#  [488, 784],
#  [488, 783],
#  [488, 782],
#  [488, 781],
#  [488, 780],
# ...

# %%
count = 0
tmp = []
for i in df_duplicate:
  if i in tmp:
    continue
  if i in df:
    count +=1 
    tmp.append(i)

# %%
count
# Out:
# 5373
